# %% [markdown]
# #1. 依存関係のインストール / ライブラリのインポート

# %%
# !pip -q install gymnasium stable-baselines3 sb3-contrib numpy tensorboard
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 8.6 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
workspace = '/content/drive/MyDrive/RL Summer 2025/最終課題/'

# %cd /content/drive/MyDrive/RL Summer 2025/最終課題/
# Out:
# /content/drive/MyDrive/RL Summer 2025/最終課題

# %%
# !sudo apt install tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (702 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tree.
# ...

# %%
# !tree
# Out:
# .
# ├── code1.ipynb
# ├── code2.ipynb
# ├── inspect_episode.py
# ├── logs
# │   └── yacht_ppo
# │       ├── best
# │       ├── ckpt
# │       │   └── ppo_maskable_12800000_steps.zip
# │       ├── eval
# │       ├── interrupt
# │       ├── MaskablePPO_20250919_041853_1
# │       │   └── events.out.tfevents.1758255539.5d0c3bf4ced4.5702.0
# │       ├── MaskablePPO_20250919_054201_1
# │       │   └── events.out.tfevents.1758260527.2a9f03c002fb.5361.0
# │       ├── MaskablePPO_20250921_025401_1
# │       │   └── events.out.tfevents.1758423249.f2553cc132ae.31999.0
# │       ├── MaskablePPO_20250923_062343_1
# │       │   └── events.out.tfevents.1758608633.9c044150237a.7581.0
# │       ├── MaskablePPO_20250923_064841_1
# │       │   └── events.out.tfevents.1758610128.9c044150237a.14940.0
# │       ├── MaskablePPO_20250924_051435_1
# │       │   └── events.out.tfevents.1758690886.9aec8c739426.9269.0
# │       ├── MaskablePPO_20250924_075437_1
# ...

# %% [markdown]
# #2. ヨットの1人プレイ用 Gymnasium 環境

# %% [markdown]
# #3. 学習

# %% [markdown]
# #3-2. 学習用スクリプト(``train_ppo.py``)

# %% [markdown]
# ## 3-3. Tensorboard

# %%
# %load_ext tensorboard
# %reload_ext tensorboard
# %tensorboard --logdir ./logs/yacht_ppo --port 6006
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Failed to launch TensorBoard (exited with 255).
# Contents of stderr:
# 2025-09-29 16:01:08.208765: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759161668.229655    7920 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759161668.235775    7920 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ./model6/train_ppo.py \
  --obs-augment --obs-add-scores --obs-progress \
  --mask-keep-all \
  --total-timesteps 50000000 \
  --log-dir ./logs/yacht_ppo \
  --save-path ./models/yacht_maskable_ppo_v8.zip
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# | train/                  |             |
# |    approx_kl            | 0.010356795 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.000133    |
# |    loss                 | -0.0482     |
# |    n_updates            | 5320        |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 0.0249      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.4        |
# |    ep_rew_mean          | 1.85        |
# | time/                   |             |
# |    fps                  | 3683        |
# |    iterations           | 534         |
# |    time_elapsed         | 9500        |
# |    total_timesteps      | 34996224    |
# ...

# %% [markdown]
# #4. 評価

# %%
# !python model6/evaluate_model.py \
  --model-path ./models/yacht_maskable_ppo_v8.zip \
  --mode auto \
  --mask-keep-all \
  --seed 42 \
  --episodes 100
# Out:
# 2025-09-25 15:48:44.035692: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758815324.056362   80132 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758815324.062931   80132 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758815324.079066   80132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# # 5. プレイ状況

# %%
# !python model6/visualize_play.py \
  --model-path ./models/yacht_maskable_ppo_v8.zip \
  --vecnorm-path ./logs/yacht_ppo/vecnorm_latest.pkl \
  --mode auto \
  --episodes 10 \
  --seed 1
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# | Sixes      |      |        | 0         | ✓       |
# | Choice     |      |        | 17        | ✓       |
# | FourDice   |      |        | 0         | ✓       |
# | FullHouse  | X    | 23     | 0         |         |
# | S.Straight |      |        | 0         | ✓       |
# | B.Straight |      |        | 0         | ✓       |
# | Yacht      |      |        | 0         | ✓       |
# +------------+------+--------+-----------+---------+
# Action: SCORE       -> Aces  raw=1
#  -> Scored. TotalScore so far: 27 | UpperSum=4/63
#
# [Turn 04 | Roll 1/3] Dice = [4, 1, 4, 4, 1] | UpperSum=4/63
# +------------+------+--------+-----------+---------+
# | Category   | Used | Scored | Immediate | Allowed |
# +------------+------+--------+-----------+---------+
# | Aces       | X    | 1      | 2         |         |
# | Deuces     |      |        | 0         | ✓       |
# | Threes     | X    | 3      | 0         |         |
# ...
